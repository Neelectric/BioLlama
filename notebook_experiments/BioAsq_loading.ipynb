# %%
#load BioASQ-trainingDataset5b.json as dictionary
import json

with open('../BioASQ-training5b/BioASQ-trainingDataset5b.json', 'rb') as json_file:
    json_data = json_file.read().decode('utf-8')

data = json.loads(json_data)

num = 0
for question in data['questions']:
    if question['type'] == 'factoid':
        num += 1
        print(question['body'])
        print(question['exact_answer'])
print(num)
# Out:
# Which thyroid hormone transporter is implicated in thyroid hormone resistance syndrome?
# ['TH monocarboxylate transporter 8 (MCT8) mutation is implicated in the TH resistance syndrome']
# Name synonym of Acrokeratosis paraneoplastica.
# [['Bazex syndrome']]
# Orteronel was developed for treatment of which cancer?
# [['castration-resistant prostate cancer']]
# Which is the protein that is encoded by the gene GLT8D1?
# [['glycosyltransferase 8 domain containing 1']]
# Where is the protein Pannexin1 located?
# [['plasma membrane']]
# What is the mode of inheritance of Wilson's disease?
# ['autosomal recessive']
# What is the mode of inheritance of Facioscapulohumeral muscular dystrophy (FSHD)?
# ['autosomal dominant']
# What kind of chromatography is HILIC?
# [['Hydrophilic Interaction Chromatography']]
# What is the structural fold of bromodomain proteins?
# [['All-alpha-helical fold']]
# Which MAP kinase phosphorylates the transcription factor c-jun?
# ...

# %%
line = " "
if not line.strip():
    print("empty")
# Out:
# empty
